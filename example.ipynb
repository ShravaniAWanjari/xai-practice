# %%
pip install shap
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/545.2 kB ? eta -:--:--
#    ---------------------------------------- 545.2/545.2 kB 9.1 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    ------------------------- -------------- 1.8/2.8 MB 8.4 MB/s eta 0:00:01
#    ---------------------------------------- 2.8/2.8 MB 7.8 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/30.3 MB ? eta -:--:--
#    - -------------------------------------- 1.3/30.3 MB 8.4 MB/s eta 0:00:04
#    --- ------------------------------------ 2.6/30.3 MB 6.9 MB/s eta 0:00:05
#    ----- ---------------------------------- 3.9/30.3 MB 6.9 MB/s eta 0:00:04
#    ------- -------------------------------- 5.5/30.3 MB 6.7 MB/s eta 0:00:04
#    -------- ------------------------------- 6.8/30.3 MB 6.7 MB/s eta 0:00:04
# ...

# %%
from
